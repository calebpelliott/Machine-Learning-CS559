# %% [markdown]
# # <center> Project 1 - Unsupervised Learning Classification</center>
# ## <center> Due: Oct 15$^{th}$ 11:59 PM</center>
#
# In this project, we are going to implement models. Unfortunately, the data set, `CS559_Fall21_Project1_02.csv`, is not labeled except the target, `Class`, and therefore, we can not straightly use supervised leanring algorithms until we learn about data - using unsupervised learning techniques in preprocessing is essential. To build models, we are allowed to use any of provided modules and libraries. **The exploratory and feature engineerings are required but not limited - all your work and process must be justified and explained in notebook.**
#
# ### Models:
# - You are going to build three different classifiers using KMeans, K Nearest Neighbor (KNN), and Logistic Regression.
#     - KMeans: KMeans arbitrary use ID indices. Cluster ID indicates the subgroup number each observation belongs to and **it does not neccessary need to have the same ID as the target ID**. The task is to check whether the model clusters and subgroups each observation to the same classes. Then perform data preprocessing in order to subgroup observations correctly as much as possible. In order to check the accuracy of clustering, the cluster IDs  may need to be **relabeled** to match with their subgroup `Class` IDs.
#     - KNN: The accuracy of KNN will likely to decrease as k value increases. The task is to determine the threshold of k value reaches to **95%**.
#     - Logistic Regression: There are several assumptions/conditions needed in order for Logistic Regression to perform well. The task is to EDA to verify if the data is suitable for Logistic Regression and perform data preprocessing to raise the accuracy of model as high as possible. When the model was applied to the raw data, the accuracy was around 35%.
# - In this project, we are not interested in optimizing the models by tunning hyperparameters. Therefore, validation and testing are not necessary. Use the entire dataset as a train data set.
# - Accuracy Report: The accuracy is the accuracy of trained model (remember that we do not split the data set). The accuracy must be reported in Data Frame format as an example shown below. When you report the accuracy of models, please provide the name of algorithms, number of features used, and the accuracy in percentile.
# |Model Number | Algorithm (s)| Number of features | Accuracy (%)|
# |---|---|---|---|
# | 0 | Logistic Regression | 3 | 35%|
# | 1 | KMeans | -- | -- |
# | 2 | KNN | -- | -- |
# | 3 | Logistic Regression | -- | -- |
#
# ### Grade Scheme:
#
# | Components | Maximum Points |
# | --- | --- |
# | Effort (cleanness, completeness, etc)| 20 |
# | EDA and Feature Engineering (w/ visualizations) | 20 |
# | Modeling | 20 |
# | Explanation (w/ visualizations) | 20 |
# | Result | 20 |
#
#
# ### Submission:
# - No formal report. However, all work (EDA, Preprocessing, Modeling) must be **explained and summarized** at the end of each model, not in the middle of implementations.
# - Submit the notebook and its exported HTML files.
# - Considering the working period of the project, **NO LATE SUBMISSIONS ARE ACCEPTED**.
# - No resubmissions due to incorrect files, corrections, etc.

# %% [markdown]
# #### Below, the libraries needed for this project are provided and plotting in 2-D and 3-D are also provided.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

from sklearn import metrics
from scipy.spatial.distance import cdist
from sklearn.preprocessing import MinMaxScaler, StandardScaler, normalize
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %%
def plot_2D(df,comp1,comp2,target):
    sns.scatterplot(x=comp1,y=comp2,data=df,hue=target)

def plot_3D(df, comp1,comp2,comp3,target):
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(df[comp1],df[comp2],df[comp3],c=df[target])
    ax.set_xlabel(comp1)
    ax.set_ylabel(comp2)
    ax.set_zlabel(comp3)
    plt.show()

# %%
df = pd.read_csv('./CS559_Fall21_Project1_02.csv')

# %%
df.head(5)
# Out:
#    var0    var1    var2     var3     var4     var5     var6     var7     var8  \
# 0     0  9.4202 -4.3507  10.3764  0.66768  0.33387  0.33355  0.33399  0.33367
# 1     1  9.7044 -4.4601  10.6803  0.66749  0.33360  0.33352  0.33345  0.33363
# 2     2  9.8075 -4.0894  10.6259  0.66742  0.33347  0.33315  0.33301  0.33364
# 3     3  9.2771 -4.0349  10.1166  0.66782  0.33322  0.33394  0.33379  0.33380
# 4     4  9.6447 -3.5968  10.2936  0.66768  0.33391  0.33301  0.33306  0.33326
#
#       var9  Class
# 0  0.33391      1
# 1  0.33395      1
# 2  0.33364      1
# 3  0.33391      1
# 4  0.33329      1

# %%
plot_2D(df,'var1', 'var2','Class')

# %%
plot_3D(df,'var1','var2','var3','Class')

# %% [markdown]
# ### Project 1 Starts from here
#
# #### Model 1: KMeans

# %% [markdown]
# ##### EDA / Preprocessing

# %%
##### EDA / Preprocessing starts here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   var0    7500 non-null   int64
#  1   var1    7500 non-null   float64
#  2   var2    7500 non-null   float64
#  3   var3    7500 non-null   float64
#  4   var4    7500 non-null   float64
#  5   var5    7500 non-null   float64
#  6   var6    7500 non-null   float64
#  7   var7    7500 non-null   float64
#  8   var8    7500 non-null   float64
#  9   var9    7500 non-null   float64
#  10  Class   7500 non-null   int64
# dtypes: float64(9), int64(2)
# memory usage: 644.7 KB

# %%
df["Class"].value_counts()
# Out:
# 4    1251
# 2    1251
# 6    1251
# 1    1249
# 5    1249
# 3    1249
# Name: Class, dtype: int64

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
corr_matrix = df.corr()
corr_matrix["Class"].sort_values(ascending=False)
# Out:
# Class    1.000000
# var0     0.986013
# var9     0.654867
# var8     0.392910
# var2     0.136978
# var7     0.130868
# var1    -0.046463
# var6    -0.130842
# var3    -0.252095
# var5    -0.393054
# var4    -0.654540
# Name: Class, dtype: float64

# %%
plot_2D(df,'var4', 'Class','Class')

# %%
dumm = pd.get_dummies(df.Class)
newdf = df.join(dumm)
corr = newdf.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_8ed74_row0_col0,#T_8ed74_row1_col1,#T_8ed74_row2_col2,#T_8ed74_row3_col3,#T_8ed74_row4_col4,#T_8ed74_row4_col11,#T_8ed74_row5_col5,#T_8ed74_row5_col12,#T_8ed74_row6_col6,#T_8ed74_row6_col13,#T_8ed74_row7_col7,#T_8ed74_row7_col14,#T_8ed74_row8_col8,#T_8ed74_row8_col15,#T_8ed74_row9_col9,#T_8ed74_row9_col16,#T_8ed74_row10_col10,#T_8ed74_row11_col4,#T_8ed74_row11_col11,#T_8ed74_row12_col5,#T_8ed74_row12_col12,#T_8ed74_row13_col6,#T_8ed74_row13_col13,#T_8ed74_row14_col7,#T_8ed74_row14_col14,#T_8ed74_row15_col8,#T_8ed74_row15_col15,#T_8ed74_row16_col9,#T_8ed74_row16_col16{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_8ed74_row0_col1,#T_8ed74_row10_col1{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_8ed74_row0_col2,#T_8ed74_row0_col7,#T_8ed74_row0_col14,#T_8ed74_row10_col2,#T_8ed74_row10_col7,#T_8ed74_row10_col14{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_8ed74_row0_col3{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_8ed74_row0_col4,#T_8ed74_row0_col5,#T_8ed74_row0_col11,#T_8ed74_row0_col12{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_8ed74_row0_col6,#T_8ed74_row0_col13{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_8ed74_row0_col8,#T_8ed74_row0_col15{
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }#T_8ed74_row0_col9,#T_8ed74_row0_col16{
#             background-color:  #f4987a;
#             color:  #000000;
#         }#T_8ed74_row0_col10,#T_8ed74_row10_col0{
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }#T_8ed74_row1_col0{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_8ed74_row1_col2{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_8ed74_row1_col3,#T_8ed74_row2_col3{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_8ed74_row1_col4,#T_8ed74_row1_col11,#T_8ed74_row5_col4,#T_8ed74_row5_col11,#T_8ed74_row6_col4,#T_8ed74_row6_col11,#T_8ed74_row7_col4,#T_8ed74_row7_col11,#T_8ed74_row8_col4,#T_8ed74_row8_col11,#T_8ed74_row9_col4,#T_8ed74_row9_col11,#T_8ed74_row12_col4,#T_8ed74_row12_col11,#T_8ed74_row13_col4,#T_8ed74_row13_col11,#T_8ed74_row14_col4,#T_8ed74_row14_col11,#T_8ed74_row15_col4,#T_8ed74_row15_col11,#T_8ed74_row16_col4,#T_8ed74_row16_col11{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_8ed74_row1_col5,#T_8ed74_row1_col12{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_8ed74_row1_col6,#T_8ed74_row1_col13{
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }#T_8ed74_row1_col7,#T_8ed74_row1_col14{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_8ed74_row1_col8,#T_8ed74_row1_col15,#T_8ed74_row3_col7,#T_8ed74_row3_col9,#T_8ed74_row3_col14,#T_8ed74_row3_col16,#T_8ed74_row4_col0,#T_8ed74_row4_col2,#T_8ed74_row4_col6,#T_8ed74_row4_col10,#T_8ed74_row4_col13,#T_8ed74_row5_col6,#T_8ed74_row5_col13,#T_8ed74_row7_col1,#T_8ed74_row7_col6,#T_8ed74_row7_col13,#T_8ed74_row8_col6,#T_8ed74_row8_col13,#T_8ed74_row9_col3,#T_8ed74_row9_col6,#T_8ed74_row9_col13,#T_8ed74_row10_col4,#T_8ed74_row10_col5,#T_8ed74_row10_col11,#T_8ed74_row10_col12,#T_8ed74_row11_col0,#T_8ed74_row11_col2,#T_8ed74_row11_col6,#T_8ed74_row11_col10,#T_8ed74_row11_col13,#T_8ed74_row12_col6,#T_8ed74_row12_col13,#T_8ed74_row14_col1,#T_8ed74_row14_col6,#T_8ed74_row14_col13,#T_8ed74_row15_col6,#T_8ed74_row15_col13,#T_8ed74_row16_col3,#T_8ed74_row16_col6,#T_8ed74_row16_col13{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_8ed74_row1_col9,#T_8ed74_row1_col10,#T_8ed74_row1_col16{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_8ed74_row2_col0,#T_8ed74_row7_col10,#T_8ed74_row14_col10{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_8ed74_row2_col1{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_8ed74_row2_col4,#T_8ed74_row2_col11{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_8ed74_row2_col5,#T_8ed74_row2_col12{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_8ed74_row2_col6,#T_8ed74_row2_col13{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_8ed74_row2_col7,#T_8ed74_row2_col14,#T_8ed74_row6_col0,#T_8ed74_row13_col0{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_8ed74_row2_col8,#T_8ed74_row2_col15{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_8ed74_row2_col9,#T_8ed74_row2_col16{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_8ed74_row2_col10{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_8ed74_row3_col0{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_8ed74_row3_col1{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_8ed74_row3_col2{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_8ed74_row3_col4,#T_8ed74_row3_col11{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_8ed74_row3_col5,#T_8ed74_row3_col12{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_8ed74_row3_col6,#T_8ed74_row3_col8,#T_8ed74_row3_col13,#T_8ed74_row3_col15{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_8ed74_row3_col10{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_8ed74_row4_col1,#T_8ed74_row11_col1{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_8ed74_row4_col3,#T_8ed74_row11_col3{
#             background-color:  #dcdddd;
#             color:  #000000;
#         }#T_8ed74_row4_col5,#T_8ed74_row4_col12,#T_8ed74_row6_col5,#T_8ed74_row6_col12,#T_8ed74_row7_col5,#T_8ed74_row7_col12,#T_8ed74_row8_col5,#T_8ed74_row8_col12,#T_8ed74_row9_col5,#T_8ed74_row9_col12,#T_8ed74_row11_col5,#T_8ed74_row11_col12,#T_8ed74_row13_col5,#T_8ed74_row13_col12,#T_8ed74_row14_col5,#T_8ed74_row14_col12,#T_8ed74_row15_col5,#T_8ed74_row15_col12,#T_8ed74_row16_col5,#T_8ed74_row16_col12{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_8ed74_row4_col7,#T_8ed74_row4_col14,#T_8ed74_row5_col7,#T_8ed74_row5_col14,#T_8ed74_row6_col7,#T_8ed74_row6_col14,#T_8ed74_row8_col7,#T_8ed74_row8_col14,#T_8ed74_row9_col7,#T_8ed74_row9_col14,#T_8ed74_row11_col7,#T_8ed74_row11_col14,#T_8ed74_row12_col7,#T_8ed74_row12_col14,#T_8ed74_row13_col7,#T_8ed74_row13_col14,#T_8ed74_row15_col7,#T_8ed74_row15_col14,#T_8ed74_row16_col7,#T_8ed74_row16_col14{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_8ed74_row4_col8,#T_8ed74_row4_col15,#T_8ed74_row5_col8,#T_8ed74_row5_col15,#T_8ed74_row6_col8,#T_8ed74_row6_col15,#T_8ed74_row7_col8,#T_8ed74_row7_col15,#T_8ed74_row9_col8,#T_8ed74_row9_col15,#T_8ed74_row11_col8,#T_8ed74_row11_col15,#T_8ed74_row12_col8,#T_8ed74_row12_col15,#T_8ed74_row13_col8,#T_8ed74_row13_col15,#T_8ed74_row14_col8,#T_8ed74_row14_col15,#T_8ed74_row16_col8,#T_8ed74_row16_col15{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_8ed74_row4_col9,#T_8ed74_row4_col16,#T_8ed74_row5_col0,#T_8ed74_row5_col9,#T_8ed74_row5_col10,#T_8ed74_row5_col16,#T_8ed74_row6_col9,#T_8ed74_row6_col16,#T_8ed74_row7_col9,#T_8ed74_row7_col16,#T_8ed74_row8_col9,#T_8ed74_row8_col16,#T_8ed74_row11_col9,#T_8ed74_row11_col16,#T_8ed74_row12_col0,#T_8ed74_row12_col9,#T_8ed74_row12_col10,#T_8ed74_row12_col16,#T_8ed74_row13_col9,#T_8ed74_row13_col16,#T_8ed74_row14_col9,#T_8ed74_row14_col16,#T_8ed74_row15_col9,#T_8ed74_row15_col16{
#             background-color:  #6c8ff1;
#             c

# %%
newdf = newdf[['var4','var5','var6','var7','var8','var9',1,2,3,4,5,6]]
corr = newdf.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_ca63d_row0_col0,#T_ca63d_row0_col6,#T_ca63d_row1_col1,#T_ca63d_row1_col7,#T_ca63d_row2_col2,#T_ca63d_row2_col8,#T_ca63d_row3_col3,#T_ca63d_row3_col9,#T_ca63d_row4_col4,#T_ca63d_row4_col10,#T_ca63d_row5_col5,#T_ca63d_row5_col11,#T_ca63d_row6_col0,#T_ca63d_row6_col6,#T_ca63d_row7_col1,#T_ca63d_row7_col7,#T_ca63d_row8_col2,#T_ca63d_row8_col8,#T_ca63d_row9_col3,#T_ca63d_row9_col9,#T_ca63d_row10_col4,#T_ca63d_row10_col10,#T_ca63d_row11_col5,#T_ca63d_row11_col11{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_ca63d_row0_col1,#T_ca63d_row0_col2,#T_ca63d_row0_col3,#T_ca63d_row0_col4,#T_ca63d_row0_col5,#T_ca63d_row0_col7,#T_ca63d_row0_col8,#T_ca63d_row0_col9,#T_ca63d_row0_col10,#T_ca63d_row0_col11,#T_ca63d_row1_col0,#T_ca63d_row1_col2,#T_ca63d_row1_col3,#T_ca63d_row1_col4,#T_ca63d_row1_col5,#T_ca63d_row1_col6,#T_ca63d_row1_col8,#T_ca63d_row1_col9,#T_ca63d_row1_col10,#T_ca63d_row1_col11,#T_ca63d_row2_col0,#T_ca63d_row2_col1,#T_ca63d_row2_col3,#T_ca63d_row2_col4,#T_ca63d_row2_col5,#T_ca63d_row2_col6,#T_ca63d_row2_col7,#T_ca63d_row2_col9,#T_ca63d_row2_col10,#T_ca63d_row2_col11,#T_ca63d_row3_col0,#T_ca63d_row3_col1,#T_ca63d_row3_col2,#T_ca63d_row3_col4,#T_ca63d_row3_col5,#T_ca63d_row3_col6,#T_ca63d_row3_col7,#T_ca63d_row3_col8,#T_ca63d_row3_col10,#T_ca63d_row3_col11,#T_ca63d_row4_col0,#T_ca63d_row4_col1,#T_ca63d_row4_col2,#T_ca63d_row4_col3,#T_ca63d_row4_col5,#T_ca63d_row4_col6,#T_ca63d_row4_col7,#T_ca63d_row4_col8,#T_ca63d_row4_col9,#T_ca63d_row4_col11,#T_ca63d_row5_col0,#T_ca63d_row5_col1,#T_ca63d_row5_col2,#T_ca63d_row5_col3,#T_ca63d_row5_col4,#T_ca63d_row5_col6,#T_ca63d_row5_col7,#T_ca63d_row5_col8,#T_ca63d_row5_col9,#T_ca63d_row5_col10,#T_ca63d_row6_col1,#T_ca63d_row6_col2,#T_ca63d_row6_col3,#T_ca63d_row6_col4,#T_ca63d_row6_col5,#T_ca63d_row6_col7,#T_ca63d_row6_col8,#T_ca63d_row6_col9,#T_ca63d_row6_col10,#T_ca63d_row6_col11,#T_ca63d_row7_col0,#T_ca63d_row7_col2,#T_ca63d_row7_col3,#T_ca63d_row7_col4,#T_ca63d_row7_col5,#T_ca63d_row7_col6,#T_ca63d_row7_col8,#T_ca63d_row7_col9,#T_ca63d_row7_col10,#T_ca63d_row7_col11,#T_ca63d_row8_col0,#T_ca63d_row8_col1,#T_ca63d_row8_col3,#T_ca63d_row8_col4,#T_ca63d_row8_col5,#T_ca63d_row8_col6,#T_ca63d_row8_col7,#T_ca63d_row8_col9,#T_ca63d_row8_col10,#T_ca63d_row8_col11,#T_ca63d_row9_col0,#T_ca63d_row9_col1,#T_ca63d_row9_col2,#T_ca63d_row9_col4,#T_ca63d_row9_col5,#T_ca63d_row9_col6,#T_ca63d_row9_col7,#T_ca63d_row9_col8,#T_ca63d_row9_col10,#T_ca63d_row9_col11,#T_ca63d_row10_col0,#T_ca63d_row10_col1,#T_ca63d_row10_col2,#T_ca63d_row10_col3,#T_ca63d_row10_col5,#T_ca63d_row10_col6,#T_ca63d_row10_col7,#T_ca63d_row10_col8,#T_ca63d_row10_col9,#T_ca63d_row10_col11,#T_ca63d_row11_col0,#T_ca63d_row11_col1,#T_ca63d_row11_col2,#T_ca63d_row11_col3,#T_ca63d_row11_col4,#T_ca63d_row11_col6,#T_ca63d_row11_col7,#T_ca63d_row11_col8,#T_ca63d_row11_col9,#T_ca63d_row11_col10{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_ca63d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >var4</th>        <th class="col_heading level0 col1" >var5</th>        <th class="col_heading level0 col2" >var6</th>        <th class="col_heading level0 col3" >var7</th>        <th class="col_heading level0 col4" >var8</th>        <th class="col_heading level0 col5" >var9</th>        <th class="col_heading level0 col6" >1</th>        <th class="col_heading level0 col7" >2</th>        <th class="col_heading level0 col8" >3</th>        <th class="col_heading level0 col9" >4</th>        <th class="col_heading level0 col10" >5</th>        <th class="col_heading level0 col11" >6</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca63d_level0_row0" class="row_heading level0 row0" >var4</th>
#                         <td id="T_ca63d_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_ca63d_row0_col1" class="data row0 col1" >-0.199162</td>
#                         <td id="T_ca63d_row0_col2" class="data row0 col2" >-0.200029</td>
#                         <td id="T_ca63d_row0_col3" class="data row0 col3" >-0.200025</td>
#                         <td id="T_ca63d_row0_col4" class="data row0 col4" >-0.200033</td>
#                         <td id="T_ca63d_row0_col5" class="data row0 col5" >-0.200108</td>
#                         <td id="T_ca63d_row0_col6" class="data row0 col6" >0.999518</td>
#                         <td id="T_ca63d_row0_col7" class="data row0 col7" >-0.199121</td>
#                         <td id="T_ca63d_row0_col8" class="data row0 col8" >-0.199966</td>
#                         <td id="T_ca63d_row0_col9" class="data row0 col9" >-0.200046</td>
#                         <td id="T_ca63d_row0_col10" class="data row0 col10" >-0.199909</td>
#                         <td id="T_ca63d_row0_col11" class="data row0 col11" >-0.200092</td>
#             </tr>
#             <tr>
#                         <th id="T_ca63d_level0_row1" class="row_heading level0 row1" >var5</th>
#                         <td id="T_ca63d_row1_col0" class="data row1 col0" >-0.199162</td>
#                         <td id="T_ca63d_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_ca63d_row1_col2" class="data row1 col2" >-0.200102</td>
#                         <td id="T_ca63d_row1_col3" class="data row1 col3" >-0.200172</td>
#                         <td id="T_ca63d_row1_col4" class="data row1 col4" >-0.200055</td>
#                         <td id="T_ca63d_row1_col5" class="data row1 col5" >-0.200198</td>
#                         <td id="T_ca63d_row1_col6" class="data row1 col6" >-0.200041</td>
#                         <td id="T_ca63d_row1_col7" class="data row1 col7" >0.999997</td>
#                         <td id="T_ca63d_row1_col8" class="data row1 col8" >-0.199994</td>
#                         <td id="T_ca63d_row1_col9" class="data row1 col9" >-0.200179</td>
#                         <td id="T_ca63d_row1_col10" class="data row1 col10" >-0.199970</td>
#                         <td id="T_ca63d_row1_col11" class="data row1 col11" >-0.200196</td>
#             </tr>
#             <tr>
#                         <th id="T_ca63d_level0_row2" class="row_heading level0 row2" >var6</th>
#                         <td id="T_ca63d_row2_col0" class="data row2 col0" >-0.200029</td>
#                         <td id="T_ca63d_row2_col1" class="data row2 col1" >-0.200102</td>
#                         <td id="T_ca63d_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_ca63d_row2_col3" class="data row2 col3" >-0.199156</td>
#                         <td id="T_ca63d_row2_col4" class="data row2 col4" >-0.200007</td>
#                         <td id="T_ca63d_row2_col5" class="data row2 col5" >-0.200076</td>
#                         <td id="T_ca63d_row2_col6" class="data row2 col6" >-0.199869</td>
#                         <td id="T_ca63d_row2_col7" class="data row2 col7" >-0.200106</td>
#                         <td id="T_ca63d_row2_col8" class="data row2 col8" >0.999517</td>
#                         <td id="T_ca63d_row2_col9" class="data row2 col9" >-0.199148</td>
#                         <td id="T_ca63d_row2_col10" class="data row2 col10" >-0.199927</td>
#                         <td id="T_ca63d_row2_col11" class="data row2 col11" >-0.200082</td>
#             </tr>
#             <tr>
#                         <th id="T_ca63d_level0_row3" class="row_heading level0 row3" >var7</th>
#                         <td id="T_ca63d_row3_col0" class="data row3 col0" >-0.200025</td>
#                         <td id="T_ca63d_row3_col1" class="data row3 col1" >-0.200172</td>
#                         <td id="T_ca63d_row3_col2" class="data row3 col2" >-0.199156</td>
#                         <td id="T_ca63d_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_ca63d_row3_col4" class="data row3 col4" >-0.200106</td>
#                         <td id="T_ca63d_row3_col5" class="data row3 col5" >-0.200161</

# %%
new_df = df[['var1', 'var2', 'var3', 'var4','var5', 'var6', 'var7', 'var8', 'var9']]

std = new_df.loc[:].values
std = StandardScaler().fit_transform(std)

pca = PCA(n_components=3)
principalComponents = pca.fit_transform(std)

principalDf = pd.DataFrame(data=principalComponents, columns=['p1', 'p2', 'p3'])
principalDf['target'] = df['Class']
plot_3D(principalDf,'p1','p2','p3','target')

# %%
kmeans = KMeans()
def plot_inertia(km, X, n_cluster_range):
    inertias = []
    for i in n_cluster_range:
        km.set_params(n_clusters=i)
        km.fit(X)
        inertias.append(km.inertia_)
    plt.plot(n_cluster_range, inertias, marker='o')
    plt.title('Elbow method')
    plt.xlabel('Number of clusters')
    plt.ylabel('Inertia')
    plt.show()
    
    tabular_result = pd.DataFrame(inertias, 
                                  index = ["n = {}".format(i) for i in range(1, len(inertias)+1)], 
                                  columns=['Inertia'])
    
    return tabular_result

new_df = principalDf[['p1', 'p2', 'p3']]
plot_inertia(kmeans, new_df, range(1, 10))
# Out:
#             Inertia
# n = 1  41427.656056
# n = 2  27337.971047
# n = 3  19204.168587
# n = 4  11128.148620
# n = 5   8044.835428
# n = 6   5336.880425
# n = 7   4366.694523
# n = 8   3533.940513
# n = 9   2868.203706

# %% [markdown]
# ##### Model Implementation

# %%
##### Model Implementation starts here
kmeans = KMeans()
kmeans.set_params(n_clusters=6)
kmeans.fit(new_df)

km_guess = kmeans.predict(new_df)

# %% [markdown]
# ##### Summary:

# %% [markdown]
# Through EDA, a few important things were found.
#
# First by plotting histograms, it can be seen that var1, var2, and var3 are somewhat normally distributed. It can also be seen that var4, var5, var6, var7, var8, and var9 are 'quasi-categorical' in that they seem to only take on values around 0.33 and 0.66. Finally, the target 'Class' is categorical ranging from 1 through 6.
#
# Second by looking at the correlation to 'Class' on the raw data, it can be seen that the data isn't very useful. This is because we are finding correlation to the numerical values of Class and not necessaraly with the categories themselves. Because of this, it was decided that it would be best to add 'categorical' columns ranging from Class 1 through Class 6 where the column value will indicate whether the data belongs to that class (where 1 indicates it is of the specified class and 0 indicates it is not).
#
# Third, even though there is a very strong correlation between var0 and Class, var0 will not be used since it is simply enumerating the data.
#
# Fourth, the first and second heatmap of correlations shows very strong relationships between var4-var9 and class1-class 6 respectively.
#
# Fifth, by standardizing the features and using PCA, it is possible to cleanly seperate the data by class and then use KMeans to accuratley classify the data using the output of PCA to train it.
#
# Lastly, the elbow graph clearly shows that n=6 is the best number of clusters to use, that is confirmed to be the truth since we already know there are 6 different classes in the data set.

# %% [markdown]
# #### Model 2: KNN

# %% [markdown]
# ##### EDA / Preprocessing

# %%
##### EDA / Preprocessing starts here
new_df = df[['var1', 'var2', 'var3']]
def calcK(guess):
    count = 0
    class_guesses = []
    for _ in range(6):
        class_guesses.append(guess[count : count + 1250])
        count += 1250

    tright = 0
    for cg in class_guesses:
        cg = cg.tolist()
        mode = max(set(cg), key=cg.count)
        right = cg.count(mode)
        tright += right
    k = tright / 7500 * 100
    return k

accuracy = []
for k in range(1,21):
    knn = KNeighborsClassifier(k)
    knn.fit(new_df, df.iloc[:,-1])
    knn_guess = knn.predict(new_df)
    accuracy.append(calcK(knn_guess))
accuracy
# Out:
# [99.96000000000001,
#  99.65333333333334,
#  99.69333333333333,
#  99.64,
#  99.58666666666667,
#  99.58666666666667,
#  99.53333333333333,
#  99.53333333333333,
#  99.45333333333333,
#  99.52,
#  99.44,
#  99.45333333333333,
#  99.45333333333333,
#  99.49333333333334,
#  99.49333333333334,
#  99.49333333333334,
#  99.48,
#  99.46666666666667,
#  99.46666666666667,
#  99.42666666666666]

# %%
k=500
below95 = False
while not below95:
    knn = KNeighborsClassifier(k)
    knn.fit(new_df, df.iloc[:,-1])
    knn_guess = knn.predict(new_df)
    accuracy = calcK(knn_guess)
    if accuracy < 95:
        break
    k+=1
k
# Out:
# 509

# %%
plot_3D(df,'var1','var2','var3','Class')

# %% [markdown]
# ##### Model Implementation

# %%
##### Model Implementation starts here

knn = KNeighborsClassifier(k)
knn.fit(new_df, df.iloc[:,-1])

knn_guess = knn.predict(new_df)

# %% [markdown]
# #### Summary:

# %% [markdown]
# To avoid coliniarity and to simplify the model, var4-var9 should not be used. Graphing var1-var3 suggests that using those features would be good for KNN and the variables are aproximately normally distributed from the histogram made of all the feautures.
#
# A quick analysis of n_neighbors shows that an n_neighbors=1 is sufficient in achieveing the highest level of accuracy.
#
# It can be seen that a k of 509 drops the accuracy below 95%.

# %% [markdown]
# #### Model 3: Logistic Regression

# %% [markdown]
# ##### EDA / Preprocessing

# %%
##### EDA / Preprocessing starts here
new_df = df[['var4', 'var5', 'var6', 'var7', 'var8', 'var9']]
new_df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
dumm = pd.get_dummies(df.Class)
newdf = df.join(dumm)
newdf = newdf[['var4','var5','var6','var7','var8','var9',1,2,3,4,5,6]]
corr = newdf.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_9891e_row0_col0,#T_9891e_row0_col6,#T_9891e_row1_col1,#T_9891e_row1_col7,#T_9891e_row2_col2,#T_9891e_row2_col8,#T_9891e_row3_col3,#T_9891e_row3_col9,#T_9891e_row4_col4,#T_9891e_row4_col10,#T_9891e_row5_col5,#T_9891e_row5_col11,#T_9891e_row6_col0,#T_9891e_row6_col6,#T_9891e_row7_col1,#T_9891e_row7_col7,#T_9891e_row8_col2,#T_9891e_row8_col8,#T_9891e_row9_col3,#T_9891e_row9_col9,#T_9891e_row10_col4,#T_9891e_row10_col10,#T_9891e_row11_col5,#T_9891e_row11_col11{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_9891e_row0_col1,#T_9891e_row0_col2,#T_9891e_row0_col3,#T_9891e_row0_col4,#T_9891e_row0_col5,#T_9891e_row0_col7,#T_9891e_row0_col8,#T_9891e_row0_col9,#T_9891e_row0_col10,#T_9891e_row0_col11,#T_9891e_row1_col0,#T_9891e_row1_col2,#T_9891e_row1_col3,#T_9891e_row1_col4,#T_9891e_row1_col5,#T_9891e_row1_col6,#T_9891e_row1_col8,#T_9891e_row1_col9,#T_9891e_row1_col10,#T_9891e_row1_col11,#T_9891e_row2_col0,#T_9891e_row2_col1,#T_9891e_row2_col3,#T_9891e_row2_col4,#T_9891e_row2_col5,#T_9891e_row2_col6,#T_9891e_row2_col7,#T_9891e_row2_col9,#T_9891e_row2_col10,#T_9891e_row2_col11,#T_9891e_row3_col0,#T_9891e_row3_col1,#T_9891e_row3_col2,#T_9891e_row3_col4,#T_9891e_row3_col5,#T_9891e_row3_col6,#T_9891e_row3_col7,#T_9891e_row3_col8,#T_9891e_row3_col10,#T_9891e_row3_col11,#T_9891e_row4_col0,#T_9891e_row4_col1,#T_9891e_row4_col2,#T_9891e_row4_col3,#T_9891e_row4_col5,#T_9891e_row4_col6,#T_9891e_row4_col7,#T_9891e_row4_col8,#T_9891e_row4_col9,#T_9891e_row4_col11,#T_9891e_row5_col0,#T_9891e_row5_col1,#T_9891e_row5_col2,#T_9891e_row5_col3,#T_9891e_row5_col4,#T_9891e_row5_col6,#T_9891e_row5_col7,#T_9891e_row5_col8,#T_9891e_row5_col9,#T_9891e_row5_col10,#T_9891e_row6_col1,#T_9891e_row6_col2,#T_9891e_row6_col3,#T_9891e_row6_col4,#T_9891e_row6_col5,#T_9891e_row6_col7,#T_9891e_row6_col8,#T_9891e_row6_col9,#T_9891e_row6_col10,#T_9891e_row6_col11,#T_9891e_row7_col0,#T_9891e_row7_col2,#T_9891e_row7_col3,#T_9891e_row7_col4,#T_9891e_row7_col5,#T_9891e_row7_col6,#T_9891e_row7_col8,#T_9891e_row7_col9,#T_9891e_row7_col10,#T_9891e_row7_col11,#T_9891e_row8_col0,#T_9891e_row8_col1,#T_9891e_row8_col3,#T_9891e_row8_col4,#T_9891e_row8_col5,#T_9891e_row8_col6,#T_9891e_row8_col7,#T_9891e_row8_col9,#T_9891e_row8_col10,#T_9891e_row8_col11,#T_9891e_row9_col0,#T_9891e_row9_col1,#T_9891e_row9_col2,#T_9891e_row9_col4,#T_9891e_row9_col5,#T_9891e_row9_col6,#T_9891e_row9_col7,#T_9891e_row9_col8,#T_9891e_row9_col10,#T_9891e_row9_col11,#T_9891e_row10_col0,#T_9891e_row10_col1,#T_9891e_row10_col2,#T_9891e_row10_col3,#T_9891e_row10_col5,#T_9891e_row10_col6,#T_9891e_row10_col7,#T_9891e_row10_col8,#T_9891e_row10_col9,#T_9891e_row10_col11,#T_9891e_row11_col0,#T_9891e_row11_col1,#T_9891e_row11_col2,#T_9891e_row11_col3,#T_9891e_row11_col4,#T_9891e_row11_col6,#T_9891e_row11_col7,#T_9891e_row11_col8,#T_9891e_row11_col9,#T_9891e_row11_col10{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_9891e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >var4</th>        <th class="col_heading level0 col1" >var5</th>        <th class="col_heading level0 col2" >var6</th>        <th class="col_heading level0 col3" >var7</th>        <th class="col_heading level0 col4" >var8</th>        <th class="col_heading level0 col5" >var9</th>        <th class="col_heading level0 col6" >1</th>        <th class="col_heading level0 col7" >2</th>        <th class="col_heading level0 col8" >3</th>        <th class="col_heading level0 col9" >4</th>        <th class="col_heading level0 col10" >5</th>        <th class="col_heading level0 col11" >6</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9891e_level0_row0" class="row_heading level0 row0" >var4</th>
#                         <td id="T_9891e_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_9891e_row0_col1" class="data row0 col1" >-0.199162</td>
#                         <td id="T_9891e_row0_col2" class="data row0 col2" >-0.200029</td>
#                         <td id="T_9891e_row0_col3" class="data row0 col3" >-0.200025</td>
#                         <td id="T_9891e_row0_col4" class="data row0 col4" >-0.200033</td>
#                         <td id="T_9891e_row0_col5" class="data row0 col5" >-0.200108</td>
#                         <td id="T_9891e_row0_col6" class="data row0 col6" >0.999518</td>
#                         <td id="T_9891e_row0_col7" class="data row0 col7" >-0.199121</td>
#                         <td id="T_9891e_row0_col8" class="data row0 col8" >-0.199966</td>
#                         <td id="T_9891e_row0_col9" class="data row0 col9" >-0.200046</td>
#                         <td id="T_9891e_row0_col10" class="data row0 col10" >-0.199909</td>
#                         <td id="T_9891e_row0_col11" class="data row0 col11" >-0.200092</td>
#             </tr>
#             <tr>
#                         <th id="T_9891e_level0_row1" class="row_heading level0 row1" >var5</th>
#                         <td id="T_9891e_row1_col0" class="data row1 col0" >-0.199162</td>
#                         <td id="T_9891e_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_9891e_row1_col2" class="data row1 col2" >-0.200102</td>
#                         <td id="T_9891e_row1_col3" class="data row1 col3" >-0.200172</td>
#                         <td id="T_9891e_row1_col4" class="data row1 col4" >-0.200055</td>
#                         <td id="T_9891e_row1_col5" class="data row1 col5" >-0.200198</td>
#                         <td id="T_9891e_row1_col6" class="data row1 col6" >-0.200041</td>
#                         <td id="T_9891e_row1_col7" class="data row1 col7" >0.999997</td>
#                         <td id="T_9891e_row1_col8" class="data row1 col8" >-0.199994</td>
#                         <td id="T_9891e_row1_col9" class="data row1 col9" >-0.200179</td>
#                         <td id="T_9891e_row1_col10" class="data row1 col10" >-0.199970</td>
#                         <td id="T_9891e_row1_col11" class="data row1 col11" >-0.200196</td>
#             </tr>
#             <tr>
#                         <th id="T_9891e_level0_row2" class="row_heading level0 row2" >var6</th>
#                         <td id="T_9891e_row2_col0" class="data row2 col0" >-0.200029</td>
#                         <td id="T_9891e_row2_col1" class="data row2 col1" >-0.200102</td>
#                         <td id="T_9891e_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_9891e_row2_col3" class="data row2 col3" >-0.199156</td>
#                         <td id="T_9891e_row2_col4" class="data row2 col4" >-0.200007</td>
#                         <td id="T_9891e_row2_col5" class="data row2 col5" >-0.200076</td>
#                         <td id="T_9891e_row2_col6" class="data row2 col6" >-0.199869</td>
#                         <td id="T_9891e_row2_col7" class="data row2 col7" >-0.200106</td>
#                         <td id="T_9891e_row2_col8" class="data row2 col8" >0.999517</td>
#                         <td id="T_9891e_row2_col9" class="data row2 col9" >-0.199148</td>
#                         <td id="T_9891e_row2_col10" class="data row2 col10" >-0.199927</td>
#                         <td id="T_9891e_row2_col11" class="data row2 col11" >-0.200082</td>
#             </tr>
#             <tr>
#                         <th id="T_9891e_level0_row3" class="row_heading level0 row3" >var7</th>
#                         <td id="T_9891e_row3_col0" class="data row3 col0" >-0.200025</td>
#                         <td id="T_9891e_row3_col1" class="data row3 col1" >-0.200172</td>
#                         <td id="T_9891e_row3_col2" class="data row3 col2" >-0.199156</td>
#                         <td id="T_9891e_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_9891e_row3_col4" class="data row3 col4" >-0.200106</td>
#                         <td id="T_9891e_row3_col5" class="data row3 col5" >-0.200161</

# %%
newdf = df[['var4','var5','var6','var7','var8','var9', 'Class']]
plot_2D(df,'var4', 'var5','Class')

# %% [markdown]
# ##### Model Implementation

# %%
##### Model Implementation starts here
new_df = df[['var4', 'var5', 'var6', 'var7', 'var8', 'var9']]
lr = LogisticRegression()
lr.fit(new_df, df.iloc[:,-1])

lr_guess = lr.predict(new_df)

# %% [markdown]
# ##### Summary:

# %% [markdown]
# Based on the analysis done above, var4-var9 was used because of its strong correlation with the target, the fact that it is binary (taking on only the values .33 and .66), the fact that there seems to be no multicollinearity based on the low correlations between the features, the fact that there is a large sample size, and that there are no outliers.
#
# There seems to be independence between observations which is good for this model. There are no extreme outliers.

# %% [markdown]
# ### Final Result Table:

# %% [markdown]
# In the result table, show only the **best result** obtained in each model. If the dataset were splitted into train and test sets, report the average of accuracy of train and test sets.

# %%
km_k = calcK(km_guess)
knn_k = calcK(knn_guess)
lr_k = calcK(lr_guess)

Result1 = {'Model Number': [0,1,2], 'Algorithm':['KMeans','KNN','Logistic Regression'],'Number of Features': ['3 (afer PCA)',3,6],
           'Accuracy':[km_k,knn_k,lr_k]}

Result1 = pd.DataFrame(Result1, columns = ['Model Number', 'Algorithm','Number of Features','Accuracy'])
Result1
# Out:
#    Model Number            Algorithm Number of Features   Accuracy
# 0             0               KMeans       3 (afer PCA)  99.960000
# 1             1                  KNN                  3  94.946667
# 2             2  Logistic Regression                  6  99.960000

# %% [markdown]
# All three models were able to perform to very high degrees of accuracy after a combination of EDA, scaling, and feature selection. Features were selected and/or scaled based on the model and the information that was able to be ascertained from EDA.
